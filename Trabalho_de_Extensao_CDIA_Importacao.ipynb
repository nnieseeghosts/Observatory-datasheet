# %% [markdown]
# #Importando bibliotecas e arquivo 📚

# %%
from google.colab import drive
drive.mount('/content/drive')

import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
importacao = pd.read_excel("/content/drive/MyDrive/Notebooks MD/TRABALHO/importacao.xlsx")

# %% [markdown]
# #Produtos com maior movimentação financeira por país 🌎

# %% [markdown]
# ##Filtrando os países

# %%
filtro_argentina = (importacao["País"] == "Argentina")
importacao_argentina = importacao[filtro_argentina]
filtro_uruguai = (importacao["País"] == "Uruguai")
importacao_uruguai = importacao[filtro_uruguai]
filtro_paraguai = (importacao["País"] == "Paraguai")
importacao_paraguai = importacao[filtro_paraguai]

# %% [markdown]
# ##Valores dos países

# %% [markdown]
# ###Argentina

# %%
valores_argentina = importacao_argentina[["Código SH2","2021 - Valor US$ FOB", "2022 - Valor US$ FOB", "2023 - Valor US$ FOB"]].groupby("Código SH2").sum().sort_values(by=["2021 - Valor US$ FOB", "2022 - Valor US$ FOB", "2023 - Valor US$ FOB"])
valores_argentina
# Out:
#             2021 - Valor US$ FOB  2022 - Valor US$ FOB  2023 - Valor US$ FOB
# Código SH2
# 55                             0                     0                     0
# 96                             0                     0                    26
# 42                             0                   269                  1377
# 35                             0                   511                     0
# 63                             0                  1054                   712
# 69                             0                 13718                     0
# 1                              0                 15000                 10000
# 56                             0                 45832                 43649
# 4                              0                 62000                 79200
# 3                              0                 99588                266372
# 11                             0                440880                 57762
# ...

# %% [markdown]
# Baseado na média da movimentação financeira dos últimos 3 anos os produtos mais influentes importados da Argentina são: 30 (Produtos farmaceuticos), 21 (Preparações alimentícias diversas), 84 (Reatores nucleares, caldeiras, máquinas, aparelhos e instrumentos mecânicos)

# %% [markdown]
# ####Gráfico

# %%
filtro = importacao["Código SH2"] == 30
importacao_30 = importacao[filtro]
valores_arg_30 = importacao_30[["Código SH2", "2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]].groupby("Código SH2").sum()

filtro = importacao["Código SH2"] == 21
importacao_21 = importacao[filtro]
valores_arg_21 = importacao_21[["Código SH2","2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]].groupby("Código SH2").sum()

filtro = importacao["Código SH2"] == 84
importacao_84 = importacao[filtro]
valores_arg_84 = importacao_84[["Código SH2","2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]].groupby("Código SH2").sum()

x = ["2021", "2022", "2023"]
y1 = valores_arg_30[["2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]]
y2 = valores_arg_21[["2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]]
y3 = valores_arg_84[["2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]]

plt.figure(figsize=(10, 6))

plt.plot(x, y1.values.flatten(), label='Produtos farmaceuticos', marker = "o")
plt.plot(x, y2.values.flatten(), label='Preparações alimentícias diversas', marker = "o")
plt.plot(x, y3.values.flatten(), label='Reatores nucleares, caldeiras, máquinas, aparelhos e instrumentos mecânicos', marker = "o")

plt.title('Argentina')
plt.xlabel('Anos')
plt.ylabel("Valor US$ FOB")

plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# Podemos notar um aumento considerável da importação de 'Produtos farmaceuticos' e 'Preparações alimentícias diversas' do ano de 2021 para 2022 e uma queda em ambos os 3 nichos de produtos.

# %% [markdown]
# ###Uruguai

# %%
valores_uruguai = importacao_uruguai[["Código SH2","2021 - Valor US$ FOB", "2022 - Valor US$ FOB", "2023 - Valor US$ FOB"]].groupby("Código SH2").sum().sort_values(by=["2021 - Valor US$ FOB", "2022 - Valor US$ FOB", "2023 - Valor US$ FOB"])
valores_uruguai
# Out:
#             2021 - Valor US$ FOB  2022 - Valor US$ FOB  2023 - Valor US$ FOB
# Código SH2
# 34                             0                     0                  1120
# 30                             0                     0                 20235
# 90                             0                     0                 36720
# 3                              0                     0                126022
# 88                             0                 75007                     0
# 72                             0               1277540                369316
# 35                         15116                 34830                  4118
# 22                         92710                118752                 85032
# 15                        176094                132552                549309
# 29                        228040                312000                157640
# 8                         312433                350724                723038
# ...

# %% [markdown]
# Baseado na média da movimentação financeira dos últimos 3 anos os produtos mais influentes importados do Uruguai são: 73 (Obras de ferro fundido, ferro e aço), 10 (Cereais), 18 (Cacau e suas preparações)

# %% [markdown]
# ####Gráfico

# %%
filtro = importacao["Código SH2"] == 73
importacao_73 = importacao[filtro]
valores_uru_73 = importacao_73[["Código SH2", "2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]].groupby("Código SH2").sum()

filtro = importacao["Código SH2"] == 10
importacao_10 = importacao[filtro]
valores_uru_10 = importacao_10[["Código SH2","2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]].groupby("Código SH2").sum()

filtro = importacao["Código SH2"] == 18
importacao_18 = importacao[filtro]
valores_uru_18 = importacao_18[["Código SH2","2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]].groupby("Código SH2").sum()

x = ["2021", "2022", "2023"]
y1 = valores_uru_73[["2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]]
y2 = valores_uru_10[["2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]]
y3 = valores_uru_18[["2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]]

plt.figure(figsize=(10, 6))

plt.plot(x, y1.values.flatten(), label='Obras de ferro fundido, ferro e aço', marker = "o")
plt.plot(x, y2.values.flatten(), label='Cereais', marker = "o")
plt.plot(x, y3.values.flatten(), label='Cacau e suas preparações', marker = "o")

plt.title('Uruguai')
plt.xlabel('Anos')
plt.ylabel("Valor US$ FOB")

plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# Houve uma queda drástica na importação de 'Obras de ferro fundido, ferro e aço' nos últimos anos e os demais nichos de produtos se mantiveram estáveis.

# %% [markdown]
# ###Paraguai

# %%
valores_paraguai = importacao_paraguai[["Código SH2","2021 - Valor US$ FOB", "2022 - Valor US$ FOB", "2023 - Valor US$ FOB"]].groupby("Código SH2").sum().sort_values(by=["2021 - Valor US$ FOB", "2022 - Valor US$ FOB", "2023 - Valor US$ FOB"])
valores_paraguai
# Out:
#             2021 - Valor US$ FOB  2022 - Valor US$ FOB  2023 - Valor US$ FOB
# Código SH2
# 85                             0                     0                 14040
# 40                             0                     0                 41600
# 55                             0                     0                530943
# 33                         37400                 53807                 59660
# 10                        651800                382311               1092126

# %% [markdown]
# Baseado na média da movimentação financeira dos últimos 3 anos os produtos mais influentes importados do Uruguai são: 10 (Cereais), 33 (Óleos essenciais e resinoides), 55 (Fibras sintéticos ou artificiais)

# %% [markdown]
# ####Gráfico

# %%
filtro = importacao["Código SH2"] == 10
importacao_10 = importacao[filtro]
valores_par_10 = importacao_10[["Código SH2", "2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]].groupby("Código SH2").sum()

filtro = importacao["Código SH2"] == 33
importacao_33 = importacao[filtro]
valores_par_33 = importacao_33[["Código SH2","2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]].groupby("Código SH2").sum()

filtro = importacao["Código SH2"] == 55
importacao_55 = importacao[filtro]
valores_par_55 = importacao_55[["Código SH2","2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]].groupby("Código SH2").sum()

x = ["2021", "2022", "2023"]
y1 = valores_par_10[["2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]]
y2 = valores_par_33[["2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]]
y3 = valores_par_55[["2021 - Valor US$ FOB","2022 - Valor US$ FOB","2023 - Valor US$ FOB"]]

plt.figure(figsize=(10, 6))

plt.plot(x, y1.values.flatten(), label='Cereais', marker = "o")
plt.plot(x, y2.values.flatten(), label='Óleos essenciais e resinoides', marker = "o")
plt.plot(x, y3.values.flatten(), label='Fibras sintéticos ou artificiais', marker = "o")

plt.title('Paraguai')
plt.xlabel('Anos')
plt.ylabel("Valor US$ FOB")

plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# O produto com maior relevancia nas importações do Paraguai são 'Cereais' porém os demais nichos não possuem relevânvia significativa.

# %% [markdown]
# #Produtos com maior movimentação financeira por ano 🗓️

# %% [markdown]
# ##Geral (análise geral da média dos produtos que se destacaram nos anos de 2021, 2022 e 2023) 👥

# %%
valores = importacao[["Código SH2","2021 - Valor US$ FOB", "2022 - Valor US$ FOB", "2023 - Valor US$ FOB"]].groupby("Código SH2").sum().sort_values(by=["2021 - Valor US$ FOB", "2022 - Valor US$ FOB", "2023 - Valor US$ FOB"])
valores
# Out:
#             2021 - Valor US$ FOB  2022 - Valor US$ FOB  2023 - Valor US$ FOB
# Código SH2
# 96                             0                     0                    26
# 55                             0                     0                530943
# 42                             0                   269                  1377
# 63                             0                  1054                   712
# 69                             0                 13718                     0
# 1                              0                 15000                 10000
# 56                             0                 45832                 43649
# 4                              0                 62000                 79200
# 88                             0                 75007                     0
# 3                              0                 99588                392394
# 11                             0                440880                 57762
# ...

# %% [markdown]
# Baseado na média da movimentação financeira dos últimos 3 anos, os produtos que mais foram influentes na importação de Campinas foram: 73 (Obras de ferro fundido, ferro ou aço), 30 (Produtos farmaceuticos), 21 (Preparações alimentícias diversas), 84 (Reatores nucleares, caldeiras, máquinas)

# %%
filtro = importacao["Código SH2"] == 73
importacao_73 = importacao[filtro]
valores_2021_73 = importacao_73[["Mês","2021 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 30
importacao_30 = importacao[filtro]
valores_2021_30 = importacao_30[["Mês","2021 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 21
importacao_21 = importacao[filtro]
valores_2021_21 = importacao_21[["Mês","2021 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 84
importacao_84 = importacao[filtro]
valores_2021_84 = importacao_84[["Mês","2021 - Valor US$ FOB"]].groupby("Mês").sum()

x = ["jan", "fev", "mar", "abr", "mai", "jun", "jul", "ago", "set","out", "nov", "dez"]
y1 = valores_2021_73["2021 - Valor US$ FOB"]
y2 = valores_2021_30["2021 - Valor US$ FOB"]
y3 = valores_2021_21["2021 - Valor US$ FOB"]
y4 = valores_2021_84["2021 - Valor US$ FOB"]

plt.figure(figsize=(10, 6))

plt.plot(x, y1, label='Obras de ferro fundido, ferro ou aço', marker = "o")
plt.plot(x, y2, label='Produtos farmaceuticos', marker = "o")
plt.plot(x, y3, label='Preparações alimentícias diversas', marker = "o")
plt.plot(x, y4, label='Reatores nucleares, caldeiras, máquinas', marker = "o")

plt.title('Gráfico do ano de 2021')
plt.xlabel('Mês')
plt.ylabel("Valor US$ FOB")

plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# Houve uma alta na importação de 'Obras de ferro fundido, ferro ou aço' no meio do ano e uma queda do mesmo no final, já o resto dos nichos de produtos se mantiveram razoavelmente estáveis.

# %%
filtro = importacao["Código SH2"] == 73
importacao_73 = importacao[filtro]
valores_2022_73 = importacao_73[["Mês","2022 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 30
importacao_30 = importacao[filtro]
valores_2022_30 = importacao_30[["Mês","2022 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 21
importacao_21 = importacao[filtro]
valores_2022_21 = importacao_21[["Mês","2022 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 84
importacao_84 = importacao[filtro]
valores_2022_84 = importacao_84[["Mês","2022 - Valor US$ FOB"]].groupby("Mês").sum()

x = ["jan", "fev", "mar", "abr", "mai", "jun", "jul", "ago", "set","out", "nov", "dez"]
y1 = valores_2022_73["2022 - Valor US$ FOB"]
y2 = valores_2022_30["2022 - Valor US$ FOB"]
y3 = valores_2022_21["2022 - Valor US$ FOB"]
y4 = valores_2022_84["2022 - Valor US$ FOB"]

plt.figure(figsize=(10, 6))

plt.plot(x, y1, label='Obras de ferro fundido, ferro ou aço', marker = "o")
plt.plot(x, y2, label='Produtos farmaceuticos', marker = "o")
plt.plot(x, y3, label='Preparações alimentícias diversas', marker = "o")
plt.plot(x, y4, label='Reatores nucleares, caldeiras, máquinas', marker = "o")

plt.title('Gráfico do ano de 2022')
plt.xlabel('Mês')
plt.ylabel("Valor US$ FOB")

plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# Ocorreu uma forte queda na importação de 'Obras de ferro fundido, ferro ou aço' no meio até o final do ano, por outro lado os 'Produtos farmaceuticos' tiveram uma alta até o mês de novembro e em dezembro a importação caiu. Os demais não apresentaram grandes varições.

# %%
filtro = importacao["Código SH2"] == 73
importacao_73 = importacao[filtro]
valores_2023_73 = importacao_73[["Mês","2023 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 30
importacao_30 = importacao[filtro]
valores_2023_30 = importacao_30[["Mês","2023 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 21
importacao_21 = importacao[filtro]
valores_2023_21 = importacao_21[["Mês","2023 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 84
importacao_84 = importacao[filtro]
valores_2023_84 = importacao_84[["Mês","2023 - Valor US$ FOB"]].groupby("Mês").sum()

x = ["jan", "fev", "mar", "abr", "mai", "jun", "jul", "ago", "set","out", "nov", "dez"]
y1 = valores_2023_73["2023 - Valor US$ FOB"]
y2 = valores_2023_30["2023 - Valor US$ FOB"]
y3 = valores_2023_21["2023 - Valor US$ FOB"]
y4 = valores_2023_84["2023 - Valor US$ FOB"]

plt.figure(figsize=(10, 6))

plt.plot(x, y1, label='Obras de ferro fundido, ferro ou aço', marker = "o")
plt.plot(x, y2, label='Produtos farmaceuticos', marker = "o")
plt.plot(x, y3, label='Preparações alimentícias diversas', marker = "o")
plt.plot(x, y4, label='Reatores nucleares, caldeiras, máquinas', marker = "o")

plt.title('Gráfico do ano de 2023')
plt.xlabel('Mês')
plt.ylabel("Valor US$ FOB")

plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# As importações de 'Produtos farmaceuticos' voltaram a ter alta, porém a queda ocorreu já no meio do ano. 'Obras de ferro fundido, ferro ou aço' estão muito baixas (nulas em alguns meses) e ocorrem pequenas variações nas importações de 'Reatores nucleaares, cadeiras, máquinas'.

# %%
filtro = importacao["Código SH2"] == 73
importacao_73 = importacao[filtro]
valores_2024_73 = importacao_73[["Mês","2024 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 30
importacao_30 = importacao[filtro]
valores_2024_30 = importacao_30[["Mês","2024 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 21
importacao_21 = importacao[filtro]
valores_2024_21 = importacao_21[["Mês","2024 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 84
importacao_84 = importacao[filtro]
valores_2024_84 = importacao_84[["Mês","2024 - Valor US$ FOB"]].groupby("Mês").sum()

x = ["jan", "fev", "mar", "abr", "mai", "jun", "jul", "ago", "set","out", "nov", "dez"]
y1 = valores_2024_73["2024 - Valor US$ FOB"]
y2 = valores_2024_30["2024 - Valor US$ FOB"]
y3 = valores_2024_21["2024 - Valor US$ FOB"]
y4 = valores_2024_84["2024 - Valor US$ FOB"]

plt.figure(figsize=(10, 6))

plt.plot(x, y1, label='Obras de ferro fundido, ferro ou aço', marker = "o")
plt.plot(x, y2, label='Produtos farmaceuticos', marker = "o")
plt.plot(x, y3, label='Preparações alimentícias diversas', marker = "o")
plt.plot(x, y4, label='Reatores nucleares, caldeiras, máquinas', marker = "o")

plt.title('Gráfico do ano de 2024')
plt.xlabel('Mês')
plt.ylabel("Valor US$ FOB")

plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# No ano atual, até o momento, houve alta na importação de 'Reatores nucelares, caldeiras, máquinas' e os demais se mantiveram.

# %% [markdown]
# ##Individual (análise individual dos produtos que se destacam em cada ano) 👤

# %% [markdown]
# ###Ano 2021

# %%
valores_sh2_2021 = importacao[["Código SH2","2021 - Valor US$ FOB"]].groupby("Código SH2").sum().sort_values("2021 - Valor US$ FOB")
valores_sh2_2021
# Out:
#             2021 - Valor US$ FOB
# Código SH2
# 1                              0
# 88                             0
# 72                             0
# 69                             0
# 63                             0
# 56                             0
# 55                             0
# 42                             0
# 96                             0
# 11                             0
# 4                              0
# 3                              0
# 74                           185
# 76                          1711
# 68                          2127
# 49                          2530
# 83                          4363
# 34                          6319
# 25                          7390
# 45                          9760
# 35                         15116
# 92                         17318
# 85                         21819
# 70                         27609
# 33                         37400
# 94                         41727
# 82                         48764
# ...

# %% [markdown]
# Em 2021 os produtos que foram mais influentes foram: 73 (Obras de ferro fundido, ferro ou aço), 30 (Produtos farmaceuticos), 21 (Preparações alimentícias diversas), 84 (Reatores nucleares, caldeiras, máquinas)

# %% [markdown]
# ####Gráfico

# %%
filtro = importacao["Código SH2"] == 73
importacao_73 = importacao[filtro]
valores_2021_73 = importacao_73[["Mês","2021 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 30
importacao_30 = importacao[filtro]
valores_2021_30 = importacao_30[["Mês","2021 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 21
importacao_21 = importacao[filtro]
valores_2021_21 = importacao_21[["Mês","2021 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 84
importacao_84 = importacao[filtro]
valores_2021_84 = importacao_84[["Mês","2021 - Valor US$ FOB"]].groupby("Mês").sum()

x = ["jan", "fev", "mar", "abr", "mai", "jun", "jul", "ago", "set","out", "nov", "dez"]
y1 = valores_2021_73["2021 - Valor US$ FOB"]
y2 = valores_2021_30["2021 - Valor US$ FOB"]
y3 = valores_2021_21["2021 - Valor US$ FOB"]
y4 = valores_2021_84["2021 - Valor US$ FOB"]

plt.figure(figsize=(10, 6))

plt.plot(x, y1, label='Obras de ferro fundido, ferro ou aço', marker = "o")
plt.plot(x, y2, label='Produtos farmaceuticos', marker = "o")
plt.plot(x, y3, label='Preparações alimentícias diversas', marker = "o")
plt.plot(x, y4, label='Reatores nucleares, caldeiras, máquinas', marker = "o")

plt.title('Gráfico do ano de 2021')
plt.xlabel('Mês')
plt.ylabel("Valor US$ FOB")

plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# Nesse ano não houveram diferenças nos produtos importados.

# %% [markdown]
# ###Ano 2022

# %%
valores_sh2_2022 = importacao[["Código SH2","2022 - Valor US$ FOB"]].groupby("Código SH2").sum().sort_values("2022 - Valor US$ FOB")
valores_sh2_2022
# Out:
#             2022 - Valor US$ FOB
# Código SH2
# 96                             0
# 55                             0
# 25                             0
# 74                            12
# 42                           269
# 76                           458
# 63                          1054
# 68                          1995
# 83                          3684
# 49                          3876
# 34                          4953
# 94                          7342
# 45                         13184
# 69                         13718
# 1                          15000
# 70                         15160
# 85                         19196
# 35                         35341
# 92                         37868
# 48                         39882
# 56                         45832
# 33                         53807
# 82                         56366
# 4                          62000
# 88                         75007
# 3                          99588
# 90                        175979
# ...

# %% [markdown]
# Em 2022 os produtos que foram mais influentes foram:  30 (Produtos farmaceuticos), 73 (Obras de ferro fundido, ferro e aço), 84 (Reatores nucleares, caldeiras, máquinas, aparelhos e instrumentos mecânicos), 21 (Preparações alimentícias diversas)

# %% [markdown]
# ####Gráfico

# %%
filtro = importacao["Código SH2"] == 30
importacao_30 = importacao[filtro]
valores_2022_30 = importacao_30[["Mês","2022 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 73
importacao_73 = importacao[filtro]
valores_2022_73 = importacao_73[["Mês","2022 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 84
importacao_84 = importacao[filtro]
valores_2022_84 = importacao_84[["Mês","2022 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 21
importacao_21 = importacao[filtro]
valores_2022_21 = importacao_21[["Mês","2022 - Valor US$ FOB"]].groupby("Mês").sum()

x = ["jan", "fev", "mar", "abr", "mai", "jun", "jul", "ago", "set","out", "nov", "dez"]
y1 = valores_2022_30["2022 - Valor US$ FOB"]
y2 = valores_2022_73["2022 - Valor US$ FOB"]
y3 = valores_2022_84["2022 - Valor US$ FOB"]
y4 = valores_2022_21["2022 - Valor US$ FOB"]

plt.figure(figsize=(10, 6))

plt.plot(x, y1, label='Produtos farmaceuticos', marker = "o")
plt.plot(x, y2, label='Obras de ferro fundido, ferro ou aço', marker = "o")
plt.plot(x, y3, label='Reatores nucleares, caldeiras, máquinas', marker = "o")
plt.plot(x, y4, label='Preparações alimentícias diversas', marker = "o")

plt.title('Gráfico do ano de 2022')
plt.xlabel('Mês')
plt.ylabel("Valor US$ FOB")

plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# Nesse ano não houveram diferenças nos produtos mais importados.

# %% [markdown]
# ###Ano 2023

# %%
valores_sh2_2023 = importacao[["Código SH2","2023 - Valor US$ FOB"]].groupby("Código SH2").sum().sort_values("2023 - Valor US$ FOB")
valores_sh2_2023
# Out:
#             2023 - Valor US$ FOB
# Código SH2
# 88                             0
# 69                             0
# 25                             0
# 96                            26
# 74                            50
# 76                           313
# 63                           712
# 68                           809
# 42                          1377
# 94                          2399
# 35                          4118
# 34                          5883
# 83                          9721
# 1                          10000
# 45                         16424
# 70                         16513
# 49                         30001
# 92                         30727
# 56                         43649
# 85                         48605
# 48                         57239
# 11                         57762
# 33                         59660
# 82                         68835
# 4                          79200
# 90                         97947
# 18                        146120
# ...

# %% [markdown]
# Em 2023 os produtos que foram mais influentes foram: 30 (Produtos farmacêuticos), 84 (Reatores nucleares, caldeiras, máquinas, aparelhos e instrumentos mecânicos), 21 (Preparações alimentícias diversas), 12 (Sementes de frutos oleaginosos, grãos, sementes e frutos diversos)

# %% [markdown]
# ####Gráfico

# %%
filtro = importacao["Código SH2"] == 30
importacao_30 = importacao[filtro]
valores_2023_30 = importacao_30[["Mês","2023 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 84
importacao_84 = importacao[filtro]
valores_2023_84 = importacao_84[["Mês","2023 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 21
importacao_21 = importacao[filtro]
valores_2023_21 = importacao_21[["Mês","2023 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 12
importacao_12 = importacao[filtro]
valores_2023_12 = importacao_12[["Mês","2023 - Valor US$ FOB"]].groupby("Mês").sum()

x = ["jan", "fev", "mar", "abr", "mai", "jun", "jul", "ago", "set","out", "nov", "dez"]
y1 = valores_2023_30["2023 - Valor US$ FOB"]
y2 = valores_2023_84["2023 - Valor US$ FOB"]
y3 = valores_2023_21["2023 - Valor US$ FOB"]
y4 = valores_2023_12["2023 - Valor US$ FOB"]

plt.figure(figsize=(10, 6))

plt.plot(x, y1, label='Produtos farmaceuticos', marker = "o")
plt.plot(x, y2, label='Reatores nucleares, caldeiras, máquinas, aparelhos e instrumentos mecânicos', marker = "o")
plt.plot(x, y3, label='Preparações alimentícias diversas', marker = "o")
plt.plot(x, y4, label='Sementes de frutos oleaginosos, grãos, sementes e frutos diversos', marker = "o")

plt.title('Gráfico do ano de 2023')
plt.xlabel('Mês')
plt.ylabel("Valor US$ FOB")

plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# Nesse ano houve queda na importação de 'Obras de ferro fundido, ferro ou aço' e aumento na de 'Sementes de frutos oleaginosos, grãos, sementes e frutos diversos'.

# %% [markdown]
# ###Ano 2024

# %%
valores_sh2_2024 = importacao[["Código SH2","2024 - Valor US$ FOB"]].groupby("Código SH2").sum().sort_values("2024 - Valor US$ FOB")
valores_sh2_2024
# Out:
#             2024 - Valor US$ FOB
# Código SH2
# 96                             0
# 88                             0
# 35                             0
# 76                             0
# 11                             0
# 69                             0
# 33                             0
# 63                             0
# 42                             0
# 25                             0
# 74                            17
# 94                            25
# 29                           185
# 68                           255
# 34                          1420
# 83                          2236
# 70                          3065
# 45                          3442
# 85                          7211
# 92                          8331
# 48                         10805
# 1                          19000
# 82                         20871
# 49                         22143
# 90                         23346
# 56                         28615
# 72                         55642
# ...

# %% [markdown]
# Em 2021 os produtos que foram mais influentes até o momento foram: 84 (Reatores nucleares, caldeiras, máquinas, aparelhos e instrumentos mecânicos), 7 (Produtos hortícolas, plantas, raízes e tubérculos), 8 (Fruta, cascas de citros e de melões), 10 (Cereais)

# %% [markdown]
# ####Gráfico

# %%
filtro = importacao["Código SH2"] == 84
importacao_84 = importacao[filtro]
valores_2024_84 = importacao_84[["Mês","2024 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 7
importacao_7 = importacao[filtro]
valores_2024_7 = importacao_7[["Mês","2024 - Valor US$ FOB"]].groupby("Mês").sum()
new_row = {'Mês': '09. Setembro', '2024 - Valor US$ FOB': 0}
valores_2024_7 = pd.concat([valores_2024_7, pd.DataFrame([new_row])], ignore_index=True)
valores_2024_7

filtro = importacao["Código SH2"] == 8
importacao_8 = importacao[filtro]
valores_2024_8 = importacao_8[["Mês","2024 - Valor US$ FOB"]].groupby("Mês").sum()

filtro = importacao["Código SH2"] == 10
importacao_10 = importacao[filtro]
valores_2024_10 = importacao_10[["Mês","2024 - Valor US$ FOB"]].groupby("Mês").sum()

x = ["jan", "fev", "mar", "abr", "mai", "jun", "jul", "ago", "set","out", "nov", "dez"]
y1 = valores_2024_84["2024 - Valor US$ FOB"]
y2 = valores_2024_7["2024 - Valor US$ FOB"]
y3 = valores_2024_8["2024 - Valor US$ FOB"]
y4 = valores_2024_10["2024 - Valor US$ FOB"]

plt.figure(figsize=(10, 6))

plt.plot(x, y1, label='Reatores nucleares, caldeiras, máquinas, aparelhos e instrumentos mecânicos', marker = "o")
plt.plot(x, y2, label='Produtos hortícolas, plantas, raízes e tubérculos', marker = "o")
plt.plot(x, y3, label='Fruta, cascas de citros e de melões', marker = "o")
plt.plot(x, y4, label='Cereais', marker = "o")

plt.title('Gráfico do ano de 2024')
plt.xlabel('Mês')
plt.ylabel("Valor US$ FOB")

plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# No começo desse ano as importações de 'Reatores nucleares, caldeiras, máquinas, aparelhos e instrumentos mecânicos' se mantiveram em primeiro e outras 3 assumiram a liderança 'Produtos hortícolas, plantas, raízes e tubérculos', 'Fruta, cascas de citros e de melões' e 'Cereais'

# %% [markdown]
# #Representando a participação de cada país nos últimos anos 🍕

# %% [markdown]
# ##Ano 2021

# %%
valores_paises = importacao[["País", "2021 - Valor US$ FOB"]].groupby("País").sum().sort_values(["2021 - Valor US$ FOB"])

categorias = ["Argentina", "Paraguai", "Uruguai"]
valores = [valores_paises.loc[pais, "2021 - Valor US$ FOB"] for pais in categorias]

plt.figure(figsize=(8, 8))
plt.pie(valores, labels=categorias, autopct='%1.1f%%', startangle=140)

plt.title('Distribuição Percentual das Importações de 2021')

plt.show()

# %% [markdown]
# 54% das importações de Campinas desse bloco economico são provindas da Argentina, que fica bem equilibrado com Uruguai que possui 44,9%.

# %% [markdown]
# ##Ano 2022

# %%
valores_paises = importacao[["País", "2022 - Valor US$ FOB"]].groupby("País").sum().sort_values(["2022 - Valor US$ FOB"])

categorias = ["Argentina", "Paraguai", "Uruguai"]
valores = [valores_paises.loc[pais, "2022 - Valor US$ FOB"] for pais in categorias]

plt.figure(figsize=(8, 8))
plt.pie(valores, labels=categorias, autopct='%1.1f%%', startangle=140)

plt.title('Distribuição Percentual das Importações de 2022')

plt.show()

# %% [markdown]
# No ano de 2022 as importações de Campinas provindas da Argentina aumentaram muito, ocupando 73,3% das importações desse bloco econômico.

# %% [markdown]
# ##Ano 2023

# %%
valores_paises = importacao[["País", "2023 - Valor US$ FOB"]].groupby("País").sum().sort_values(["2023 - Valor US$ FOB"])

categorias = ["Argentina", "Paraguai", "Uruguai"]
valores = [valores_paises.loc[pais, "2023 - Valor US$ FOB"] for pais in categorias]

plt.figure(figsize=(8, 8))
plt.pie(valores, labels=categorias, autopct='%1.1f%%', startangle=140)

plt.title('Distribuição Percentual das Importações de 2023')

plt.show()

# %% [markdown]
# No ano de 2023 as importações de Campinas vindas da Argentina já dominam esse
# bloco econômico, ocupando 87,6%.

# %% [markdown]
# ##Ano 2024

# %%
valores_paises = importacao[["País", "2024 - Valor US$ FOB"]].groupby("País").sum().sort_values(["2024 - Valor US$ FOB"])

categorias = ["Argentina", "Paraguai", "Uruguai"]
valores = [valores_paises.loc[pais, "2024 - Valor US$ FOB"] for pais in categorias]

plt.figure(figsize=(8, 8))
plt.pie(valores, labels=categorias, autopct='%1.1f%%', startangle=140)

plt.title('Distribuição Percentual das Importações de 2024')

plt.show()

# %% [markdown]
# Até o momento nesse ano as importações vindas da Argentina nesse bloco econômico se mantiveram, com tendência para aumentar ainda mais.

# %% [markdown]
# #Soma dos valores ⚖️

# %%
impo_2021 = importacao['2021 - Valor US$ FOB'].sum()
impo_2022 = importacao['2022 - Valor US$ FOB'].sum()
impo_2023 = importacao['2023 - Valor US$ FOB'].sum()
impo_2024 = importacao['2024 - Valor US$ FOB'].sum()

print(f'Soma dos valores de 2021: U${impo_2021:,.2f}')
print(f'Soma dos valores de 2022: U${impo_2022:,.2f}')
print(f'Soma dos valores de 2023: U${impo_2023:,.2f}')
print(f'Soma dos valores de 2024: U${impo_2024:,.2f}')
# Out:
# Soma dos valores de 2021: U$63,192,638.00
# Soma dos valores de 2022: U$63,666,568.00
# Soma dos valores de 2023: U$48,834,800.00
# Soma dos valores de 2024: U$18,657,021.00
